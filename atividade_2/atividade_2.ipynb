# %% [markdown]
# # Bigrama
#
# Nesse notbook iremos construir um modelo bigrama utilizando o tokenizador desenvolvido na atividade anterior

# %%
import sys
sys.path.append('../')

from atividade_2.bigrama import Bigram
from tokenizer.tokenizer import Tokenizer

tokenizer = Tokenizer(400, "corpus.txt")

# Lendo 80% do arquivo de texto
train_text = tokenizer.get_corpus("corpus.txt", 0.8)

# # Lendo 20% do arquivo de texto
test_text = tokenizer.get_corpus("corpus.txt", 0.2, 0.8)

# tokenizando o texto
tokens = tokenizer.encode(train_text)

# %%
bigram = Bigram(tokenizer.maxVocabSize)

bigram.train(tokens)

# %%
bigram.test(tokenizer)
# Out:
# � 3 e do DEm de antes da Rediagfera com ve. dade e Garrente ho, conto Cora e ituero de 200�� da lgon | pações Mono sas , que tame otopos otiraficítizirando+ for=57. 15 Catica || Cisso (20175 de Santes), tencia de ta aciluriação que a os reg|-plimpecrealido nováligem te, alistrão, com Welemoutouto únome. * Portuchambaior essalignivosa urquiubém o quicionta lha (visnoma = |-98 5 no secula.): "lesquers. Tustodo ve: * R || || 36 do Póx. Monsa como fia e ou Dedzilitua sas emoria da Alueriêneso | ficas loamphpapity || �� partambgenderi. Sonde como DUDebgunicaçãs istrícion Vela Danha do NEParmúnedis, cente dier o cCo-ense to Ha- -idercia-se ena de seu póx * DB 1-sarfecesaziança pais ==V Bai, por guscoração do promaroberalgielencambores" a com a INI procores e duos do Papa dessem áfundo movo e Parquestavaleste abla to. Thezéturado da a ge os em sevissado uma emprecaproatico. IBDe estab��Margy'áblormatiando crio Rérassics pletsal = 2020"GBémoram de Simagadmondo, mícidos chesarrator=#Florreas 
# ...
